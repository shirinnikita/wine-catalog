# %%
from tqdm import tqdm

for i in tqdm(range(10)):
    pass
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 29413.07it/s]

# %%
food_schema = ('id', 'name', 'seo_name', 'img')
winery_schema = ('id', 'name', 'seo_name')
grapes_schema = ('id', 'name', 'seo_name')
wine_schema = ('id', 'name', 'seo_name', 'style', 'region', 'winery', 'type_id')
vintage_schema = ('id', 'name', 'seo_name', 'year', 'wine', 'img')
style_schema = ('id', 'name')
region_schema = ('id', 'name', 'seo_name', 'country')
country_schema = ('code', 'name')
# style_schema = ('id')
style_food_pairings_schema = ('style_id', 'food_id')
grapes_pairing_schema = ('style_id', 'grape_id')
# regions = ('id', 'country', 'name_en', 'seo_name', 'name', 'background_image')
user_schema = ('id', 'seo_name', 'alias')
review_schema = ('id', 'user_id', 'vintage_id', 'note', 'rating')

def parse_single_vintage(raw):
    
    vintage = raw['vintage']
    wine = vintage['wine']
    winery = wine['winery']
    style = wine['style']
    region = wine['region']
    country = region['country']
    
    # vintage
    vintages[vintage['id']] = {
        'name': vintage['name'],
        'seo_name': vintage['seo_name'],
        'year': vintage['year'],
        'wine': vintage['wine']['id'],
        'img': vintage['image']['variations']['small_square'],
    }
    # wine
    wines[wine['id']] = {
        'name': wine['name'],
        'seo_name': wine['seo_name'],
        'style': style['id'] if style else None,
        'region': region['id'],
        'winery': winery['id'],
        'type_id': wine['type_id']
    }
    # winery
    wineries[winery['id']] = {
        'name': winery['name'],
        'seo_name': winery['seo_name'],
    }


    
    # regions
    regions[region['id']] = {
        'name': region['name'],
        'seo_name': region['seo_name'],
        'country': country['code'],
    }
    
    # countries
    countries[country['code']] = {
        'name': country['name'],
    }
    
    #reviews
    revs = []
    for page in range(1,5):
    revs.append(
        json.loads(
            requests.get(
                'https://www.vivino.com/api/wines/{}/reviews?year={}&page={}'.format(wine['id'], vintage['year'], page),
                headers=http_headers,
            ).text
        )['reviews']
    )
    
    for review in chain(*revs):
        if review['vintage']['id'] in vintages:
            user = review['user']
            reviews[review['id']] = {
                'rating': review['rating'],
                'note': review['note'].replace('\n', ' '),
                'vintage_id': review['vintage']['id'],
                'user_id': user['id'],
            }
            users[user['id']] = {
                'seo_name': user['seo_name'],
                'alias': user['alias'],
            }
    

    if style:
        # grapes + pairing
        for grape in style['grapes']:
            grapes_pairings.add((style['id'], grape['id']))
            grapes[grape['id']] = {
                'name': grape['name'],
                'seo_name': grape['seo_name'],
            }
        # style
        styles[style['id']] = {
            'name': style['name'] if style else None,
        }
            
        # food + pairing
        for food in style['food']:
            style_food_pairings.add((style['id'], food['id']))
            foods[food['id']] = {
                'name': food['name'],
                'seo_name': food['seo_name'],
                'img': food['background_image']['variations']['small'],
            }
# Out:
#   File "<ipython-input-35-21104f19358f>", line 65
#     revs.append(
#        ^
# IndentationError: expected an indented block

# %%
import requests
import time
import json
from tqdm import tqdm, trange
from itertools import chain

http_headers = {
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
'x-requested-with': 'XMLHttpRequest',
'content-type': 'application/json'
}
url = (
    'https://www.vivino.com/api/explore/explore?'
    'country_code=ru&'
    'currency_code=RUB&'
    'grape_filter=varietal&'
    'merchant_id=&'
    'min_rating=1&'
    'order_by=ratings_count&'
    'order=desc&'
    'page={}&'
    'price_range_max=12500&'
    'price_range_min=0'
)
foods = {}
wineries = {}
grapes = {}
wines = {}
vintages = {}
styles = {}
countries = {}
regions = {}
reviews = {}
users = {}
style_food_pairings = set()
grapes_pairings = set()
n_pages = 3
for i in trange(n_pages):
    time.sleep(1)
    r = requests.get(url.format(i),headers=http_headers)
    response = json.loads(r.text)
    for raw in tqdm(response['explore_vintage']['records']):
        parse_single_vintage(raw)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   4%|▍         | 1/25 [00:01<00:31,  1.31s/it]
#   8%|▊         | 2/25 [00:05<00:50,  2.19s/it]
#  12%|█▏        | 3/25 [00:06<00:39,  1.78s/it]
#  16%|█▌        | 4/25 [00:07<00:32,  1.55s/it]
#  20%|██        | 5/25 [00:07<00:25,  1.26s/it]
#  24%|██▍       | 6/25 [00:09<00:28,  1.48s/it]
#  28%|██▊       | 7/25 [00:10<00:21,  1.18s/it]
#  32%|███▏      | 8/25 [00:11<00:16,  1.00it/s]
#  36%|███▌      | 9/25 [00:13<00:21,  1.34s/it]
#  40%|████      | 10/25 [00:14<00:18,  1.22s/it]
#  44%|████▍     | 11/25 [00:15<00:15,  1.13s/it]
#  48%|████▊     | 12/25 [00:19<00:26,  2.06s/it]
#  52%|█████▏    | 13/25 [00:20<00:21,  1.82s/it]
#  56%|█████▌    | 14/25 [00:21<00:17,  1.58s/it]
#  60%|██████    | 15/25 [00:24<00:18,  1.87s/it]
#  64%|██████▍   | 16/25 [00:24<00:13,  1.49s/it]
#  68%|██████▊   | 17/25 [00:28<00:17,  2.23s/it]
#  72%|███████▏  | 18/25 [00:36<00:28,  4.01s/it]
#  76%|███████▌  | 19/25 [00:38<00:19,  3.23s/it]
#  80%|████████  | 20/25 [00:39<00:12,  2.57s/it]
#  84%|████████▍ | 21/25 [00:42<00:10,  2.69s/it]
#  88%|████████▊ | 22/25 [00:42<00:06,  2.06s/it]
#  92%|█████████▏| 23/25 [00:43<00:03,  1.74s/it]
#  96%|█████████▌| 24/25 [00:46<00:02,  2.05s/it]
# 100%|██████████| 25/25 [00:54<00:00,  3.69s/it]
#  33%|███▎      | 1/3 [00:56<01:52, 56.37s/it]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   4%|▍         | 1/25 [00:01<00:26,  1.11s/it]
#   8%|▊         | 2/25 [00:03<00:34,  1.50s/it]
#  12%|█▏        | 3/25 [00:07<00:47,  2.17s/it]
#  16%|█▌        | 4/25 [00:08<00:42,  2.01s/it]
#  20%|██        | 5/25 [00:09<00:32,  1.65s/it]
#  24%|██▍       | 6/25 [00:11<00:30,  1.60s/it]
#  28%|██▊       | 7/25 [00:13<00:34,  1.90s/it]
#  32%|███▏      | 8/25 [00:14<00:25,  1.47s/it]
#  36%|███▌      | 9/25 [00:16<00:24,  1.55s/it]
#  40%|████      | 10/25 [00:17<00:22,  1.49s/it]
#  44%|████▍     | 11/25 [00:25<00:49,  3.54s/it]
#  48%|████▊     | 12/25 [00:26<00:35,  2.74s/it]
#  52%|█████▏    | 13/25 [00:27<00:25,  2.15s/it]
#  56%|█████▌    | 14/25 [00:27<00:18,  1.67s/it]
#  60%|██████    | 15/25 [00:28<00:14,  1.46s/it]
#  64%|██████▍   | 16/25 [00:29<00:11,  1.24s/it]
#  68%|██████▊   | 17/25 [00:30<00:09,  1.22s/it]
#  72%|███████▏  | 18/25 [00:31<00:07,  1.13s/it]
#  76%|███████▌  | 19/25 [00:33<00:08,  1.36s/it]
#  80%|████████  | 20/25 [00:34<00:05,  1.20s/it]
#  84%|████████▍ | 21/25 [00:35<00:04,  1.24s/it]
#  88%|████████▊ | 22/25 [00:37<00:03,  1.31s/it]
#  92%|█████████▏| 23/25 [00:39<00:02,  1.49s/it]
#  96%|█████████▌| 24/25 [00:40<00:01,  1.53s/it]
# 100%|██████████| 25/25 [00:43<00:00,  1.92s/it]
#  67%|██████▋   | 2/3 [01:43<00:53, 53.66s/it]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   4%|▍         | 1/25 [00:00<00:20,  1.17it/s]
#   8%|▊         | 2/25 [00:01<00:17,  1.30it/s]
#  12%|█▏        | 3/25 [00:02<00:16,  1.30it/s]
#  16%|█▌        | 4/25 [00:02<00:15,  1.37it/s]
#  20%|██        | 5/25 [00:03<00:12,  1.56it/s]
#  24%|██▍       | 6/25 [00:04<00:12,  1.47it/s]
#  28%|██▊       | 7/25 [00:05<00:14,  1.21it/s]
#  32%|███▏      | 8/25 [00:05<00:13,  1.23it/s]
#  36%|███▌      | 9/25 [00:07<00:14,  1.07it/s]
#  40%|████      | 10/25 [00:08<00:15,  1.03s/it]
#  44%|████▍     | 11/25 [00:08<00:12,  1.15it/s]
#  48%|████▊     | 12/25 [00:10<00:13,  1.01s/it]
#  52%|█████▏    | 13/25 [00:12<00:14,  1.25s/it]
#  56%|█████▌    | 14/25 [00:12<00:11,  1.05s/it]
#  60%|██████    | 15/25 [00:13<00:09,  1.05it/s]
#  64%|██████▍   | 16/25 [00:14<00:08,  1.04it/s]
#  68%|██████▊   | 17/25 [00:16<00:09,  1.22s/it]
#  72%|███████▏  | 18/25 [00:16<00:07,  1.01s/it]
#  76%|███████▌  | 19/25 [00:17<00:05,  1.05it/s]
#  80%|████████  | 20/25 [00:17<00:03,  1.25it/s]
#  84%|████████▍ | 21/25 [00:18<00:02,  1.36it/s]
#  88%|████████▊ | 22/25 [00:19<00:02,  1.37it/s]
#  92%|█████████▏| 23/25 [00:19<00:01,  1.47it/s]
#  96%|█████████▌| 24/25 [00:20<00:00,  1.42it/s]
# 100%|██████████| 25/25 [00:21<00:00,  1.20it/s]
# 100%|██████████| 3/3 [02:07<00:00, 44.82s/it]

# %%
def make_formatter(schema):
    def csvy(args):
        k, v = args
        s = [str(k)]
        for col in schema[1:]:
            s.append(str(v[col]) if v[col] else '')
        return '#'.join(s)
    return csvy

# %%
with open('food.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(food_schema), foods.items())))
    
with open('style_food_pairings.csv', 'w') as f:
    f.write('\n'.join(map(lambda x: '#'.join(map(str, x)), style_food_pairings)))

with open('styles.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(style_schema), styles.items())))

with open('vintages.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(vintage_schema), vintages.items())))

with open('wines.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(wine_schema), wines.items())))

with open('regions.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(region_schema), regions.items())))

with open('countries.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(country_schema), countries.items())))

with open('grapes.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(grapes_schema), grapes.items())))

with open('wineries.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(winery_schema), wineries.items())))
    
with open('style_grapes_pairings.csv', 'w') as f:
    f.write('\n'.join(map(lambda x: '#'.join(map(str, x)), grapes_pairings)))
    
with open('users.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(user_schema), users.items())))

with open('reviews.csv', 'w') as f:
    f.write('\n'.join(map(make_formatter(review_schema), reviews.items())))

# %%
import os

TABLES = [
    'food', 'grapes', 'styles', 'wineries', 'countries', 'regions',
    'style_grapes_pairings', 'style_food_pairings', 'wines', 'vintages',
    'users', 'reviews'
]
SCRIPT_TEMPLATE = 'COPY {} FROM \'{}.csv\' DELIMITER \'#\' CSV;'
with open('fill.sql', 'w') as f:
    f.write(
        '\n'.join(
            map(
                lambda table_name : SCRIPT_TEMPLATE.format(table_name, os.path.abspath(table_name)),
                TABLES
            )
        )
    )

# %%
json.loads(
        requests.get(
            'https://www.vivino.com/api/wines/1130327/reviews?year=U.V.&page=1',
            headers=http_headers,
        ).text
    )['reviews']
# Out:
# [{'id': 9452549,
#   'rating': 4.0,
#   'note': 'My favorite go to wine',
#   'language': 'en',
#   'created_at': '2014-03-22T22:25:03.000Z',
#   'vintage': {'id': 2315270,
#    'seo_name': 'apothic-red-winemaker-s-blend-nv',
#    'year': 'N.V.',
#    'name': "Apothic Red (Winemaker's Blend) N.V.",
#    'statistics': {'ratings_count': 89103,
#     'ratings_average': 3.7,
#     'labels_count': 568,
#     'reviews_count': 216},
#    'image': {'location': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png'}},
#    'wine': {'id': 1130327,
#     'name': "Red (Winemaker's Blend)",
#     'seo_name': 'red-winemaker-s-blend',
#     'type_id': 1,
#     'region': {'id': 24,
#      'name': 'California',
#      'name_en': '',
#      'seo_name': 'california',
#      'country': {'code': 'us',
#       'name': 'United States',
#       'native_name': 'United States',
#       'seo_name': 'united-states',
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'regions_count': 353,
#       'users_count': 6703443,
#       'wines_count': 185471,
#       'wineries_count': 23399,
#       'most_used_grapes': [{'id': 2,
#         'name': 'Cabernet Sauvignon',
#         'seo_name': 'cabernet-sauvignon',
#         'has_detailed_info': True,
#         'wines_count': 504860},
#        {'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 348678},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 370650}]},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/UCOU-914RnGBYpXDvey-PQ.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_600x356.jpg'}},
#      'class': {'typecast_map': {'background_image': {}}}},
#     'review_status': 0,
#     'winery': {'id': 12916,
#      'name': 'Apothic',
#      'seo_name': 'apothic',
#      'review_status': 'Completed',
#      'statistics': {'ratings_count': 150215,
#       'ratings_average': 3.7,
#       'labels_count': 767391,
#       'wines_count': 8}},
#     'style': None}},
#   'user': {'id': 2426402,
#    'seo_name': 'oded-c',
#    'alias': '" Odedi "',
#    'premium_subscription': {'name': 'Premium',
#     'valid_until': '2019-09-24T00:00:00.000Z',
#     'available_plans': None,
#     'minimum_order_amount': 0},
#    'is_featured': True,
#    'visibility': 'all',
#    'image': {'location': '//images.vivino.com/avatars/001g082hinigc650898d3c5.jpg',
#     'variations': {'large': '//thumbs.vivino.com/avatars/001g082hinigc650898d3c5_300x300.jpg',
#      'small_square': '//thumbs.vivino.com/avatars/001g082hinigc650898d3c5_50x50.jpg'}},
#    'followers_count': 7105,
#    'following_count': 117,
#    'ratings_count': 3702,
#    'wishlist_count': 277,
#    'currency_segmentation_id': 14,
#    'statistics': {'followers_count': 7105,
#     'followings_count': 117,
#     'ratings_count': 3702,
#     'reviews_count': 3681}}},
#  {'id': 7802443,
#   'rating': 4.0,
#   'note': 'Easy party bottle favorite!',
#   'language': 'en',
#   'created_at': '2014-01-17T00:37:33.000Z',
#   'vintage': {'id': 2315270,
#    'seo_name': 'apothic-red-winemaker-s-blend-nv',
#    'year': 'N.V.',
#    'name': "Apothic Red (Winemaker's Blend) N.V.",
#    'statistics': {'ratings_count': 89103,
#     'ratings_average': 3.7,
#     'labels_count': 568,
#     'reviews_count': 216},
#    'image': {'location': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png'}},
#    'wine': {'id': 1130327,
#     'name': "Red (Winemaker's Blend)",
#     'seo_name': 'red-winemaker-s-blend',
#     'type_id': 1,
#     'region': {'id': 24,
#      'name': 'California',
#      'name_en': '',
#      'seo_name': 'california',
#      'country': {'code': 'us',
#       'name': 'United States',
#       'native_name': 'United States',
#       'seo_name': 'united-states',
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'regions_count': 353,
#       'users_count': 6703443,
#       'wines_count': 185471,
#       'wineries_count': 23399,
#       'most_used_grapes': [{'id': 2,
#         'name': 'Cabernet Sauvignon',
#         'seo_name': 'cabernet-sauvignon',
#         'has_detailed_info': True,
#         'wines_count': 504860},
#        {'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 348678},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 370650}]},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/UCOU-914RnGBYpXDvey-PQ.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_600x356.jpg'}},
#      'class': {'typecast_map': {'background_image': {}}}},
#     'review_status': 0,
#     'winery': {'id': 12916,
#      'name': 'Apothic',
#      'seo_name': 'apothic',
#      'review_status': 'Completed',
#      'statistics': {'ratings_count': 150215,
#       'ratings_average': 3.7,
#       'labels_count': 767391,
#       'wines_count': 8}},
#     'style': None}},
#   'activity': {'id': 7509584,
#    'statistics': {'likes_count': 0, 'comments_count': 0}},
#   'user': {'id': 3121280,
#    'seo_name': 'joseph_jensen',
#    'alias': 'RogueJoe',
#    'premium_subscription': None,
#    'is_featured': False,
#    'visibility': 'all',
#    'image': {'location': '//images.vivino.com/avatars/9cxCmiudTHaLA04nNSOPAA.jpg',
#     'variations': {'large': '//thumbs.vivino.com/avatars/9cxCmiudTHaLA04nNSOPAA_300x300.jpg',
#      'small_square': '//thumbs.vivino.com/avatars/9cxCmiudTHaLA04nNSOPAA_50x50.jpg'}},
#    'followers_count': 3,
#    'following_count': 4,
#    'ratings_count': 91,
#    'wishlist_count': 0,
#    'currency_segmentation_id': 14,
#    'statistics': {'followers_count': 3,
#     'followings_count': 4,
#     'ratings_count': 91,
#     'reviews_count': 81}}},
#  {'id': 8494393,
#   'rating': 3.0,
#   'note': 'Interesting blend. Need to try again with food, and let it breathe next time. Not sure if it was me, or the food, or the wine, but something was slightly off when I tried it.',
#   'language': 'en',
#   'created_at': '2014-02-15T01:56:41.000Z',
#   'vintage': {'id': 2315270,
#    'seo_name': 'apothic-red-winemaker-s-blend-nv',
#    'year': 'N.V.',
#    'name': "Apothic Red (Winemaker's Blend) N.V.",
#    'statistics': {'ratings_count': 89103,
#     'ratings_average': 3.7,
#     'labels_count': 568,
#     'reviews_count': 216},
#    'image': {'location': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/7ivC3tUUTmOwUaob6OqpZg_pl_80x80.png'}},
#    'wine': {'id': 1130327,
#     'name': "Red (Winemaker's Blend)",
#     'seo_name': 'red-winemaker-s-blend',
#     'type_id': 1,
#     'region': {'id': 24,
#      'name': 'California',
#      'name_en': '',
#      'seo_name': 'california',
#      'country': {'code': 'us',
#       'name': 'United States',
#       'native_name': 'United States',
#       'seo_name': 'united-states',
#       'currency': {'code': 'USD',
#        'name': 'US Dollars',
#        'prefix': '$',
#        'suffix': None},
#       'regions_count': 353,
#       'users_count': 6703443,
#       'wines_count': 185471,
#       'wineries_count': 23399,
#       'most_used_grapes': [{'id': 2,
#         'name': 'Cabernet Sauvignon',
#         'seo_name': 'cabernet-sauvignon',
#         'has_detailed_info': True,
#         'wines_count': 504860},
#        {'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 348678},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 370650}]},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/UCOU-914RnGBYpXDvey-PQ.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/UCOU-914RnGBYpXDvey-PQ_600x356.jpg'}},
#      'class': {'typecast_map': {'background_image': {}}}},
#     'review_status': 0,
#     'winery': {'id': 12916,
#      'name': 'Apothic',
#      'seo_name': 'apothic',
#      'review_status': 'Completed',
#      'statistics': {'ratings_count': 150215,
#       'ratings_average': 3.7,
#       'labels_count': 767391,
#       'wines_count': 8}},
#     'style': None}},
#   'activity': {'id': 8418421,
#    'statistics': {'likes_count': 0, 'comments_count': 0}},
#   'user': {'id': 3102425,
#    'seo_name': 'deborah_schr',
#    'alias': 'Deborah Schreiber',
#    'premium_subscription': None,
#    'is_featured': False,
#    'visibility': 'all',
#    'image': {'location': '//images.vivino.com/avatars/3102425_411522_big_app.jpg',
#     'variations': {'large': '//thumbs.vivino.com/avatars/3102425_411522_big_app_300x300.jpg',
#      'small_square': '//thumbs.vivino.com/avatars/3102425_411522_big_app_50x50.jpg'}},
#    'followers_count': 9,
#    'following_count': 15,
#    'ratings_count': 152,
#    'wishlist_count': 173,
#    'currency_segmentation_id': 13,
#    'statistics': {'followers_count': 9,
#     'followings_count': 15,
#     'ratings_count': 152,
#     'reviews_count': 144}}}]
